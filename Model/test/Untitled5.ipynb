# %%
# -*- coding:utf8
# using python3
import numpy as np
import pandas as pd

####################################
# Data Path
####################################
file_path = '/Volumes/Transcend/HackNtu_2017/Security/Raw Data/TBrain_IPS_new.csv' # It comes from another code

####################################
# Reading Dating
####################################
Data = pd.read_csv(file_path)
columns = Data.columns


####################################
# Splitting Data into training set and testing set
####################################
def data_splitting(value_of_target):
	frames_train = []
	frames_val = []
	# input : value of target : list-like
	# output: frames waiting to cancatenate 
	for value in value_of_target:
		## DataFrame.drapna(): return a dataframe without any missing values
		base = Data.loc[Data['event_rule_severity'] == value].dropna()
		## sampling 80 percent of data as training set
		df1_train = base.sample(frac=0.8)
		df1_val = base.drop(df1_train.index[[i for i in range(df1_train.shape[0])]])

		frames_train.append(df1_train)
		frames_val.append(df1_val)

	return pd.concat(frames_train), pd.concat(frames_val) # Dtrain, Dval

Dtrain, Dval = data_splitting([3,4,5])

# %%
import json
def convert_str_to_nominal_variables(data2, col_name):
    # input: col_name(str)
    data_tmp = data2[col_name]
    cat = list(enumerate(list(data_tmp.unique())))
    table = dict()
    for item in cat:
        table[item[1]] = item[0]
    with open('%s.json'%(col_name), 'w') as fp:
    json.dump(table, fp)
    data2 = data2.replace({col_name: table })
    return data2
df_columns = ["device_dev_name", "device_family_name", "device_os_name", "device_type_name", "device_vendor_name",'event_rule_category']

t = 0
for name in df_columns:
	t += 1
	Dtrain = convert_str_to_nominal_variables(Dtrain, name)
	Dval = convert_str_to_nominal_variables(Dval, name)
	print ('目前進度', 1.0 * t / len(df_columns))
# Out:
# {'Canon Photo Printer': 79, 'Ooma VoIP Adapter': 10, 'Windows Phone 8.0': 43, 'D-Link Wireless AP': 17, 'OpenBSD': 66, 'Xiaomi Router': 27, 'Mitsubishi SmartTV': 72, 'iPhone/iPad/iPod': 44, 'ASUS RT Router': 21, 'Cisco 7940/7960x IP Phone': 92, 'Linux 2.4.x': 87, 'Roku Device': 12, 'Apple Watch/iPad Pro': 11, 'Debian 6': 30, 'LG SmartTV': 32, 'Amazon Kindle': 46, 'TP-LINK Wireless LAN Router': 75, 'Ubuntu 12 based distro': 64, 'Windows': 0, 'NETGEAR WNDR3000': 90, 'Cisco IP Phone': 108, 'Sony PlayStation Vita': 45, 'WD My Book World Edition': 99, 'BlackBerry': 35, 'Raspbian': 24, 'Fedora 14-16 based distro': 33, 'DD-WRT Router': 7, 'Windows 7': 15, 'Linux 2.6.x': 34, 'TiVo': 100, 'Windows Vista': 36, 'PXE Client (ZEN)': 48, 'Linux': 2, 'Sony PlayStation 4': 68, 'Windows Server 2003': 77, 'Chromecast': 42, 'NetBotz WallBotz 420E': 4, 'Ubuntu 9-10 based distro': 23, 'NEC Aterm Series': 53, 'Sipura VoIP Adaptor': 84, 'D-Link IPCam': 37, 'Philips hue': 56, 'Mac OS X': 14, 'Nokia Internet Tablet': 73, 'NETGEAR NTV300': 8, 'Synology NAS': 59, 'Trendnet Print Server': 51, 'Windows 95': 85, 'Android 6.0': 18, 'Debian-based Linux': 94, 'Windows 98 SE': 105, 'Apple AirPort Extreme': 40, 'Red Hat Linux': 1, 'Windows NT 4': 96, 'Cisco 7910 IP Phone': 109, 'Windows 8/10': 16, 'NETGEAR WNR3500L': 38, 'Hotway LanDrive': 93, 'Android 3.0-4.1': 19, 'Apple AirMac Extreme': 86, 'Windows Server 2008': 31, 'Pioneer BDP': 5, 'Samsung Gear S2': 65, 'NETGEAR WNDR4300': 22, 'Windows XP': 3, 'Windows Phone 7.5': 101, 'Nintendo Wii': 71, 'Vonage VoIP Phone': 47, 'FreeBSD 10.1': 39, 'Windows 2000': 102, 'NETGEAR WGT624v4': 88, 'PLANEX MZK Series': 28, 'Toshiba SmartTV': 104, 'Linksys Router': 63, 'Linksys RE7000': 26, 'NetBotz WallBotz 500': 6, 'Sony BDP': 9, 'NETGEAR WGR614v6': 98, 'Buffalo AirStation Series': 61, 'Kobo Aura': 69, 'Xbox 360': 57, 'Novell NetWare Client': 41, 'Samsung SmartTV': 83, 'Sharp SmartTV': 74, 'NETGEAR Router': 78, 'Cisco Catalyst 35xx': 67, 'Dell Printer': 106, 'Kyocera FS-1028MFP': 95, 'NETGEAR R6300': 97, 'Xbox': 13, 'Axis Network Camera': 54, 'Sony PlayStation 2': 49, 'Chromebook': 25, 'Brother Printer 2': 91, 'Ubuntu 11 based distro': 70, 'NetBotz WallBotz 400C': 81, 'Android 4.2-5.1': 20, 'FirefoxOS Mobile': 80, 'Belkin F5D8235-4 v2': 82, 'Cisco 7961G IP Phone': 103, 'ELECOM/PLANEX/Logitec Wireless Access Point': 50, 'Cisco 7965G IP Phone': 107, 'NETGEAR arlo': 60, 'Hewlett-Packard iLO Agent (Not Configured)': 55, 'PXE Client': 62, 'Nintendo Wii U': 52, 'Sony PlayStation 3': 29, 'VIVOTEK Network Camera': 58, 'Panasonic SmartTV': 89, 'Linux (embedded system)': 76}
# {'Canon Photo Printer': 82, 'Ooma VoIP Adapter': 6, 'Windows Phone 8.0': 54, 'D-Link Wireless AP': 51, 'Linux 2.6.x': 36, 'Xiaomi Router': 19, 'iPhone/iPad/iPod': 40, 'ASUS RT Router': 67, 'Cisco 7940/7960x IP Phone': 91, 'Linux 2.4.x': 94, 'Roku Device': 11, 'Apple Watch/iPad Pro': 39, 'Debian 6': 46, 'Apple AirPort Extreme': 56, 'Amazon Kindle': 48, 'TP-LINK Wireless LAN Router': 74, 'Ubuntu 12 based distro': 52, 'Windows': 3, 'Windows 98 SE': 92, 'Sony PlayStation Vita': 29, 'WD My Book World Edition': 33, 'BlackBerry': 42, 'Raspbian': 25, 'Fedora 14-16 based distro': 53, 'Debian-based Linux': 84, 'Windows 7': 13, 'OpenBSD': 44, 'TiVo': 63, 'Windows Vista': 16, 'PXE Client (ZEN)': 43, 'Linux': 4, 'Sony PlayStation 4': 28, 'Chromecast': 21, 'Android 3.0-4.1': 34, 'NETGEAR WNDR4300': 69, 'NetBotz WallBotz 420E': 10, 'Ubuntu 9-10 based distro': 15, 'Canon Printer': 88, 'NETGEAR WNR3500L': 60, 'Philips hue': 31, 'Mac OS X': 12, 'Nokia Internet Tablet': 76, 'NETGEAR NTV300': 8, 'Synology NAS': 61, 'Trendnet Print Server': 65, 'Android 6.0': 24, 'LG SmartTV': 20, 'Red Hat Linux': 1, 'Windows 8/10': 14, 'Hotway LanDrive': 93, 'Buffalo AirStation Series': 87, 'Pioneer BDP': 9, 'Samsung Gear S2': 70, 'D-Link IPCam': 38, 'Apple AirMac Extreme': 77, 'Windows XP': 0, 'Nintendo Wii': 66, 'Vonage VoIP Phone': 62, 'Nintendo Wii U': 37, 'Windows 2000': 89, 'Panasonic DMR': 85, 'NETGEAR WGT624v4': 32, 'PLANEX MZK Series': 72, 'Linksys Router': 41, 'Linksys RE7000': 71, 'Windows Server 2003': 86, 'NetBotz WallBotz 500': 2, 'Novell NetWare Client': 18, 'NETGEAR WGR614v6': 57, 'Windows Server 2008': 59, 'Kobo Aura': 80, 'Xbox 360': 17, 'Sony BDP': 5, 'Samsung SmartTV': 79, 'Sharp SmartTV': 73, 'NETGEAR Router': 58, 'Xbox': 22, 'Linux (embedded system)': 78, 'Axis Network Camera': 49, 'Sony PlayStation 2': 47, 'Chromebook': 35, 'Ubuntu 11 based distro': 83, 'Android 4.2-5.1': 23, 'FirefoxOS Mobile': 55, 'Belkin F5D8235-4 v2': 27, 'ELECOM/PLANEX/Logitec Wireless Access Point': 50, 'Cisco 7965G IP Phone': 90, 'NETGEAR arlo': 75, 'Hewlett-Packard iLO Agent (Not Configured)': 64, 'PXE Client': 45, 'FreeBSD 10.1': 26, 'Sony PlayStation 3': 30, 'VIVOTEK Network Camera': 68, 'Panasonic SmartTV': 81, 'DD-WRT Router': 7}
# 目前進度 0.16666666666666666
# {'Game Console': 5, 'Computer': 0, 'Smart TV &  Set-top box': 3, 'Intelligent Home Appliances': 2, 'Wearable devices': 6, 'Network & Peripheral': 1, 'Handheld': 4}
# {'Game Console': 5, 'Computer': 0, 'Smart TV &  Set-top box': 4, 'Intelligent Home Appliances': 2, 'Wearable devices': 6, 'Network & Peripheral': 1, 'Handheld': 3}
# 目前進度 0.3333333333333333
# {'Windows 95': 30, 'Windows 98 SE': 35, 'Android 6.0': 10, 'Windows Server 2008': 17, 'Linux 2.2': 1, 'BlackBerry': 18, 'Raspbian': 14, 'Maemo': 26, 'Cisco IOS': 25, 'Linux 2.6': 13, 'Windows 8/10': 9, 'Others': 4, 'Windows NT 4': 33, 'Windows 7': 8, 'XMB': 16, 'Windows Phone': 22, 'OpenBSD': 24, 'Windows Vista': 19, 'Linux': 2, 'Cisco Native Unix': 32, 'Android 4.2-5.1': 12, 'Windows Server 2003': 28, 'Android 3.0-4.1': 11, 'Windows XP': 3, 'Wii system': 23, 'VxWorks': 21, 'Apple iOS': 5, 'Windows 2000': 34, 'ChromeOS': 15, 'Linux 2.4': 31, 'FreeBSD 10.1': 20, 'Linux (embedded system)': 27, 'Mac OS X': 7, 'Xbox': 6, 'Firefox OS': 29, 'Windows': 0}
# {'Windows 98 SE': 31, 'Android 6.0': 13, 'Windows Server 2008': 25, 'Linux 2.2': 1, 'BlackBerry': 20, 'Raspbian': 14, 'Maemo': 26, 'Linux 2.6': 8, 'Windows 8/10': 7, 'Others': 2, 'Android 3.0-4.1': 11, 'XMB': 16, 'OpenBSD': 21, 'Windows Phone': 22, 'Windows Vista': 9, 'Linux': 4, 'Cisco Native Unix': 30, 'Android 4.2-5.1': 12, 'Windows Server 2003': 28, 'Wii system': 18, 'Windows XP': 0, 'VxWorks': 24, 'Apple iOS': 19, 'Windows 7': 6, 'Windows 2000': 29, 'ChromeOS': 17, 'Linux 2.4': 32, 'FreeBSD 10.1': 15, 'Linux (embedded system)': 27, 'Mac OS X': 5, 'Xbox': 10, 'Firefox OS': 23, 'Windows': 3}
# 目前進度 0.5
# {'DVR': 2, 'Multimedia Device': 7, 'Miscellaneous': 1, 'SmartWatch': 19, 'Printer': 16, 'SmartTV': 4, 'Game Console': 8, 'Wireless Lighting': 17, 'Wireless Router': 3, 'Wireless Access Point': 9, 'Android Device': 10, 'PDA': 22, 'Desktop/Laptop': 0, 'Smartphone': 13, 'NAS': 18, 'Router': 11, 'eBook Reader': 21, 'Switch': 20, 'VoIP Phone': 5, 'Tablet': 15, 'VoIP Gateway': 23, 'Scanner': 24, 'Thin Client': 12, 'Apple iOS Device': 6, 'IP Network Camera': 14}
# {'DVR': 2, 'Multimedia Device': 6, 'Miscellaneous': 1, 'SmartWatch': 19, 'Printer': 18, 'SmartTV': 5, 'Game Console': 7, 'IP Network Camera': 14, 'Wireless Router': 4, 'Wireless Access Point': 12, 'Android Device': 9, 'PDA': 20, 'Desktop/Laptop': 0, 'Smartphone': 16, 'NAS': 13, 'Router': 8, 'eBook Reader': 21, 'VoIP Phone': 3, 'Tablet': 17, 'Thin Client': 10, 'Apple iOS Device': 15, 'Wireless Lighting': 11}
# 目前進度 0.6666666666666666
# {'DD-WRT': 5, 'PLANEX HOLDING INC.': 18, 'TP-LINK Technologies Co. Ltd.': 44, 'Apple Inc.': 9, 'Belkin': 47, 'D-Link Systems Inc.': 11, 'Vonage Holdings Corp.': 26, 'NEC Corporation': 30, 'Synology Inc.': 35, 'Nintendo Co. Ltd.': 29, 'Fedora': 21, 'VIVOTEK Inc.': 34, 'Red Hat': 1, 'Philips': 33, 'Sony Corporation': 7, 'Debian': 19, 'Microsoft Corp.': 0, 'Kyocera Mita Corp.': 52, 'Amazon.com Inc.': 25, 'Hewlett-Packard': 32, 'Axis Communications': 31, 'Brother Industries Ltd.': 50, 'Sharp Corporation': 43, 'Toshiba Corporation': 55, 'ASUSTeK Computer Inc.': 13, 'Samsung Group': 37, 'Western Digital Corp.': 53, 'Canon Inc.': 45, 'FreeBSD': 23, 'NETGEAR': 6, 'LG Corporation': 20, 'BlackBerry Limited': 22, 'Linksys': 16, 'Hotway': 51, 'Panasonic Corporation': 49, 'Maemo': 42, 'Kobo Inc.': 40, 'Dell Inc.': 56, 'Raspberry Pi Foundation': 15, 'Pioneer Corporation': 4, 'OpenBSD': 38, 'TiVo': 54, 'Sipura Technology': 48, 'Netbotz': 3, 'Ubuntu': 14, 'Mitsubishi Electric Corporation': 41, 'Cisco Systems Inc.': 39, 'Buffalo Inc.': 36, 'TRENDnet': 28, 'Xiaomi Inc.': 17, 'ELECOM CO.LTD/PLANEX HOLDING INC./Logitec INC.': 27, 'Google Inc.': 12, 'Roku Inc.': 10, 'Others': 2, 'Ooma Inc.': 8, 'Novell Inc.': 24, 'Mozilla': 46}
# {'DD-WRT': 6, 'PLANEX HOLDING INC.': 40, 'TP-LINK Technologies Co. Ltd.': 42, 'Apple Inc.': 10, 'Belkin': 18, 'D-Link Systems Inc.': 22, 'Vonage Holdings Corp.': 33, 'Synology Inc.': 32, 'Nintendo Co. Ltd.': 21, 'FreeBSD': 17, 'VIVOTEK Inc.': 38, 'Red Hat': 1, 'Philips': 19, 'Sony Corporation': 4, 'Debian': 26, 'Microsoft Corp.': 0, 'Amazon.com Inc.': 27, 'Hewlett-Packard': 35, 'Axis Communications': 28, 'Sharp Corporation': 41, 'ASUSTeK Computer Inc.': 37, 'Ooma Inc.': 5, 'Western Digital Corp.': 20, 'Canon Inc.': 46, 'NETGEAR': 7, 'LG Corporation': 14, 'BlackBerry Limited': 24, 'Linksys': 23, 'Hotway': 49, 'Panasonic Corporation': 45, 'Maemo': 43, 'Kobo Inc.': 44, 'Raspberry Pi Foundation': 16, 'Mozilla': 31, 'OpenBSD': 25, 'TiVo': 34, 'Fedora': 30, 'Netbotz': 2, 'Ubuntu': 11, 'Buffalo Inc.': 47, 'Cisco Systems Inc.': 48, 'Xiaomi Inc.': 13, 'TRENDnet': 36, 'Samsung Group': 39, 'ELECOM CO.LTD/PLANEX HOLDING INC./Logitec INC.': 29, 'Google Inc.': 15, 'Roku Inc.': 9, 'Others': 3, 'Novell Inc.': 12, 'Pioneer Corporation': 8}
# 目前進度 0.8333333333333334
# {'Web Attack': 2, 'DoS/DDoS': 4, 'Access Control': 1, 'BotNet': 5, 'Virus/Worm': 6, 'Buffer Overflow': 3, 'Misc': 0, 'Backdoor/Trojan': 7}
# {'Misc': 0, 'DoS/DDoS': 2, 'Access Control': 3, 'BotNet': 5, 'Virus/Worm': 6, 'Buffer Overflow': 4, 'Web Attack': 1, 'Backdoor/Trojan': 7}
# 目前進度 1.0

# %%
df_train.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  device_dev_name  device_family_name  \
# 0      172277        172277                0                   0
# 1      502376        502376                1                   1
# 2      795932        795932                2                   0
# 3       43035         43035                3                   0
# 4      616236        616236                2                   0
#
#    device_os_name  device_type_name  device_vendor_name  event_protocol_id  \
# 0               0                 0                   0                  6
# 1               1                 1                   1                  6
# 2               2                 0                   2                  6
# 3               3                 0                   2                  6
# 4               2                 0                   2                  6
#
#   event_flow_outbound_or_inbound event_role_device_or_router  \
# 0                       outbound                      device
# 1                       outbound                      device
# 2                       outbound                      device
# 3                       outbound                      device
# 4                       outbound                      device
#
#   event_role_server_or_client  event_rule_category  event_rule_id  \
# 0                      server                    0        1130489
# 1                      server                    0        1130489
# 2                      server                    0        1130489
# 3                      server                    0        1130489
# 4                      server                    0        1130491
#
#                                      event_rule_name  \
# 0  SSL TLSv1.0 FREAK with CBC Cipher TLS_RSA_EXPO...
# 1  SSL TLSv1.0 FREAK with CBC Cipher TLS_RSA_EXPO...
# 2  SSL TLSv1.0 FREAK with CBC Cipher TLS_RSA_EXPO...
# 3  SSL TLSv1.0 FREAK with CBC Cipher TLS_RSA_EXPO...
# 4  SSL TLSv1.0 FREAK with CBC Cipher TLS_RSA_EXPO...
#
#            event_rule_reference  event_rule_severity event_self_ipv4  \
# 0  CVE-2015-0204; CVE-2015-1637                    3     10.200.10.3
# 1  CVE-2015-0204; CVE-2015-1637                    3    192.168.1.25
# 2  CVE-2015-0204; CVE-2015-1637                    3  192.168.10.114
# 3  CVE-2015-0204; CVE-2015-1637                    3   192.168.1.102
# 4  CVE-2015-0204; CVE-2015-1637                    3     192.168.0.2
#
#    event_time        router_ip
# 0          16    156.15.215.88
# 1          10   21.227.231.223
# 2          14  217.123.122.179
# 3          14  114.176.251.173
# 4          16   183.156.247.70
